# %% [markdown]
# # 🧠 ¿Qué es la programación?
#
# La **programación** es el arte de indicarle a una computadora lo que tiene que hacer mediante un conjunto de instrucciones. Podés imaginarlo como una **receta de cocina** 🧑‍🍳: cada paso debe estar claramente definido para que la máquina lo entienda y lo ejecute correctamente.
#
# Estas instrucciones se escriben en un **lenguaje especial** que llamamos **Lenguaje de Programación**, que funciona como el **idioma de las máquinas** 🖥️.
#
# ---
#
# ## 💻 ¿Qué es un lenguaje de programación?
#
# Un **lenguaje de programación** es el conjunto de instrucciones que permite a los humanos comunicarse con las computadoras. A través de él, podemos expresar **algoritmos** e **instrucciones** que la máquina puede interpretar y ejecutar.
#
# - 🧩 **Sintaxis**: son las reglas y la estructura del lenguaje (cómo se escribe).
# - 🧠 **Semántica**: es el significado de esas instrucciones (qué hacen).
#
# En resumen, es el puente entre nuestras ideas y la ejecución automática por parte de una computadora 🚀.

# %% [markdown]
# ## 🛠️ ¿Qué es un IDE?
#
# Un **IDE** (*Integrated Development Environment* o *Entorno de Desarrollo Integrado*) es una aplicación que proporciona a los programadores un conjunto de herramientas en un solo lugar para facilitar la creación de software.
#
# Combina varias funciones esenciales en una sola interfaz, lo que hace que el proceso de programación sea más **eficiente, organizado y productivo**.
#
# ---
#
# ## 🧩 Componentes Principales de un IDE
#
# - **📝 Editor de Código**
#   Área donde se escribe el código fuente. Incluye funciones como:
#   - Resaltado de sintaxis
#   - Autocompletado
#   - Sugerencias inteligentes
#
# - **🐞 Depurador (Debugger)**
#   Permite ejecutar el código paso a paso para detectar errores. Muestra el estado de las variables y el flujo del programa en tiempo real.
#
# - **🗂️ Explorador de Proyectos**
#   Organiza y permite navegar por los archivos y carpetas del proyecto de forma estructurada.
#
# - **🔨 Herramientas de Construcción (Build Tools)**
#   Automatizan tareas como la compilación, ejecución de pruebas y empaquetado del software.
#
# - **🔄 Control de Versiones**
#   Integración con sistemas como **Git**, para rastrear cambios, colaborar y gestionar versiones del proyecto.
#
# ---
#
# ## 💻 Ejemplos Populares de IDEs
#
# - **Visual Studio Code (VSCode)** – Ligero, extensible y muy popular.
# - **Jupyter Notebook** – Ideal para ciencia de datos y visualización interactiva.
# - **PyCharm** – Potente IDE especializado en Python.

# %% [markdown]
# # 🧠 Clasificacion de personalidad
#
# ## 🎯 Objetivos de la Notebook
# Clasificar a las personas como **INTROVERTIDOS** o **EXTROVERTIDOS** basándonos en su comportamiento social usando técnicas de Aprendizaje Supervisado
#
# Vamos a construir un modelo usando:
# - 🔺 Gradient Boosting
# - ⚡ Linear Regression
#
# Optimizamos hiperparámetros y evaluamos el desempeño con la  **Métrica AUC**.
# ---
#
# ## 🗂️ Tabla de Contenidos
# 1. [Introducción](#introduccion)
# 2. [Análisis Exploratorio](#analisis-exploratorio)
# 3. [Preprocesamiento de Datos](#preprocesamiento)
# 4. [Entrenamiento y Evaluación del Modelo](#entrenamiento-evaluacion)
# 5. [Importancia de Variables e Interpretabilidad](#importancia-interpretabilidad)
# 6. [Cursos sugeridos](#6--cursos-sugeridos)
#
# ---

# %% [markdown]
# ## 1. 🧭 Introducción <a name="introduccion"></a>
#
# Exploramos un conjunto de datos de personalidad para clasificar a los usuarios como introvertidos o extrovertidos, basándonos en su comportamiento.
#
# Este proyecto incluye:
# - Entendimiento de los datos
# - Limpieza y codificación
# - Ingeniería de variables
# - Modelado
# - Evaluación

# %% [markdown]
# ## 2. 📊 Análisis Exploratorio <a name="analisis-exploratorio"></a>
#
# Vamos a examinar:
# - Valores faltantes
# - Distribución de variables
# - Desbalanceo en la variable objetivo
# - Correlación entre variables

# %% [markdown]
# ## 📚 ¿Qué es una librería?
#
# En programación, una **librería** es una colección de funciones, clases y recursos predefinidos que los desarrolladores pueden utilizar para realizar tareas comunes sin tener que escribir todo el código desde cero.
#
# Las librerías permiten **ahorrar tiempo y esfuerzo**, ya que ofrecen soluciones probadas y optimizadas para problemas frecuentes.
#
# ---
#
# ## 🧩 Características de una Librería
#
# - **🔁 Reutilización de Código**
#   Permiten aprovechar código ya existente, reduciendo la duplicación de esfuerzos y mejorando la eficiencia.
#
# - **📦 Modularidad**
#   Están organizadas en módulos, lo que permite importar solo las partes necesarias para un proyecto específico.
#
# - **🛠️ Mantenimiento y Actualización**
#   Suelen ser mantenidas por comunidades o empresas, lo que garantiza mejoras constantes, seguridad y compatibilidad con nuevas versiones del lenguaje.
#
# - **📖 Facilidad de Uso**
#   Vienen acompañadas de documentación y ejemplos, lo que facilita su integración en proyectos nuevos o existentes.

# %%
# Librerias standard
import os
import warnings
warnings.filterwarnings('ignore')

# Manipulación de datos y análisis
import pandas as pd
import numpy as np

# Visualización de datos
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning - Preprocesamiento
from sklearn.preprocessing import LabelEncoder, StandardScaler, PolynomialFeatures
from sklearn.impute import SimpleImputer

# Machine Learning - Modelado y evaluación
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, roc_auc_score, f1_score

# Machine Learning - Modelos
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, StackingClassifier

# Persistencia de modelo
import joblib

df = pd.read_csv("personality_datasert.csv")
df.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert

# %%
# Mostramos información básica de los datos
print("Dataset Tamaño:", df.shape)
print("\nDataset Info:")
print(df.info())
print("\Valores Nulos:")
print(df.isnull().sum())
# Out:
# Dataset Tamaño: (2900, 8)
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2900 non-null   float64
#  1   Stage_fear                 2900 non-null   object
#  2   Social_event_attendance    2900 non-null   float64
#  3   Going_outside              2900 non-null   float64
#  4   Drained_after_socializing  2900 non-null   object
#  5   Friends_circle_size        2900 non-null   float64
#  6   Post_frequency             2900 non-null   float64
#  7   Personality                2900 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 181.4+ KB
# None
# \Valores Nulos:
# Time_spent_Alone             0
# Stage_fear                   0
# Social_event_attendance      0
# Going_outside                0
# Drained_after_socializing    0
# ...

# %%
# Diccionario de nombres nuevos (todo en minúscula y en español)
nombres_columnas = {
    'Time_spent_Alone': 'tiempo_solo',
    'Stage_fear': 'miedo_escenico',
    'Social_event_attendance': 'asistencia_eventos_sociales',
    'Going_outside': 'salir_afuera',
    'Drained_after_socializing': 'agotado_despues_socializar',
    'Friends_circle_size': 'tamano_circulo_amigos',
    'Post_frequency': 'frecuencia_publicaciones',
    'Personality': 'personalidad'
}
# Renombrar columnas
df.rename(columns=nombres_columnas, inplace=True)
# Mapear valores a español
valores_esp= {'Yes': 'Si', 'No': 'No'}

df['miedo_escenico'] = df['miedo_escenico'].map(valores_esp)
df['agotado_despues_socializar'] = df['agotado_despues_socializar'].map(valores_esp)

df['personalidad'] = df['personalidad'].map({
    'Extrovert': 'extrovertido',
    'Introvert': 'introvertido'
})
df.head()
# Out:
#    tiempo_solo miedo_escenico  asistencia_eventos_sociales  salir_afuera  \
# 0          4.0             No                          4.0           6.0
# 1          9.0             Si                          0.0           0.0
# 2          9.0             Si                          1.0           2.0
# 3          0.0             No                          6.0           7.0
# 4          3.0             No                          9.0           4.0
#
#   agotado_despues_socializar  tamano_circulo_amigos  frecuencia_publicaciones  \
# 0                         No                   13.0                       5.0
# 1                         Si                    0.0                       3.0
# 2                         Si                    5.0                       2.0
# 3                         No                   14.0                       8.0
# 4                         No                    8.0                       5.0
#
#    personalidad
# 0  extrovertido
# 1  introvertido
# ...

# %%
# Defino variables numericas; categóricas y mi target
numeric_cols = ['tiempo_solo', 'asistencia_eventos_sociales', 'salir_afuera', 'tamano_circulo_amigos', 'frecuencia_publicaciones']
categorical_cols = ['miedo_escenico', 'agotado_despues_socializar']
target = 'personalidad'

# %%
# Semilla Random
np.random.seed(42)

# %%
# Distribución de mi clase: PERSONALIDAD
plt.figure(figsize=(8, 6))
sns.countplot(x=target, data=df,palette='Set2',hue = target, legend=False)
plt.title('Distribución de los tipos de personalidad')
plt.xlabel('Personalidad')
plt.ylabel('Cantidad')
plt.show()

# %%
df.head()
# Out:
#    tiempo_solo miedo_escenico  asistencia_eventos_sociales  salir_afuera  \
# 0          4.0             No                          4.0           6.0
# 1          9.0             Si                          0.0           0.0
# 2          9.0             Si                          1.0           2.0
# 3          0.0             No                          6.0           7.0
# 4          3.0             No                          9.0           4.0
#
#   agotado_despues_socializar  tamano_circulo_amigos  frecuencia_publicaciones  \
# 0                         No                   13.0                       5.0
# 1                         Si                    0.0                       3.0
# 2                         Si                    5.0                       2.0
# 3                         No                   14.0                       8.0
# 4                         No                    8.0                       5.0
#
#    personalidad
# 0  extrovertido
# 1  introvertido
# ...

# %%
print(f"La cantidad de personas por clase es: {df['personalidad'].value_counts()}")
print()
print(f"La proporción de personas por clase es: {df['personalidad'].value_counts(normalize=True)}")
# Out:
# La cantidad de personas por clase es: personalidad
# extrovertido    1491
# introvertido    1409
# Name: count, dtype: int64
#
# La proporción de personas por clase es: personalidad
# extrovertido    0.514138
# introvertido    0.485862
# Name: proportion, dtype: float64

# %%
# Histograma de Tiempo Solo
plt.figure(figsize=(5,3))
plt.hist(df["tiempo_solo"], bins=12, color="purple", edgecolor="black")
plt.title("Distribución de tiempo_solo")
plt.xlabel("Horas")
plt.ylabel("Frecuencia")
plt.tight_layout()
plt.show()

# %%
# Distribución de variables numéricas por clase
plt.figure(figsize=(8, 6))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x=target,hue=target, y=col, data=df)
    plt.title(f'{col} por Personalidad')
plt.tight_layout()
plt.show()

# %%
# Heatmap: correlación ente variables 
plt.figure(figsize=(10, 8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt='.2f', vmin=-1, vmax=1)
plt.title('Heatmap: Correlacion de variables')
plt.show()

# %% [markdown]
# ## 3. 🧹 Preprocesamiento de Datos <a name="preprocesamiento"></a>
#
# En esta sección:
# - Imputamos valores faltantes
# - Codificamos variables categóricas
# - Normalizamos variables numéricas

# %%
#Como vimos anteriormente, el dataset no presenta nulos.

# %%
# Vamos a pasar la variable target a valor numérico:
le = LabelEncoder()
df[target] = le.fit_transform(df[target])
print(f"Clases encodeadas: {dict(zip(le.classes_, le.transform(le.classes_)))}")
# Out:
# Clases encodeadas: {'extrovertido': np.int64(0), 'introvertido': np.int64(1)}

# %%
df.personalidad.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# Name: personalidad, dtype: int64

# %%
df[categorical_cols].head()
# Out:
#   miedo_escenico agotado_despues_socializar
# 0             No                         No
# 1             Si                         Si
# 2             Si                         Si
# 3             No                         No
# 4             No                         No

# %%
# Encodedo features categóricas
cols_antes = set(df.columns)
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
cols_despues = set(df.columns)
categoricas = list(cols_despues - cols_antes)
print("Nuevas variables dummy creadas:")
print(categoricas)
# Out:
# Nuevas variables dummy creadas:
# ['agotado_despues_socializar_Si', 'miedo_escenico_Si']

# %%
# Topeo los OutLiars
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1 #Rango Intercuartilico
    limite_inf = Q1 - 1.5 * IQR
    limite_sup = Q3 + 1.5 * IQR
    df[col] = df[col].clip(lower=limite_inf, upper=limite_sup)

# %%
df.head()
# Out:
#    tiempo_solo  asistencia_eventos_sociales  salir_afuera  \
# 0          4.0                          4.0           6.0
# 1          9.0                          0.0           0.0
# 2          9.0                          1.0           2.0
# 3          0.0                          6.0           7.0
# 4          3.0                          9.0           4.0
#
#    tamano_circulo_amigos  frecuencia_publicaciones  personalidad  \
# 0                   13.0                       5.0             0
# 1                    0.0                       3.0             1
# 2                    5.0                       2.0             1
# 3                   14.0                       8.0             0
# 4                    8.0                       5.0             0
#
#    miedo_escenico_Si  agotado_despues_socializar_Si
# 0              False                          False
# 1               True                           True
# 2               True                           True
# ...

# %%
# Train-test split
X = df.drop(columns=[target])
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train.head()
# Out:
#       tiempo_solo  asistencia_eventos_sociales  salir_afuera  \
# 399           0.0                          7.0           7.0
# 2895          3.0                          7.0           6.0
# 2023          0.0                          6.0           6.0
# 2613          3.0                          4.0           6.0
# 2689          5.0                          0.0           1.0
#
#       tamano_circulo_amigos  frecuencia_publicaciones  miedo_escenico_Si  \
# 399                     4.0                  6.000000              False
# 2895                    6.0                  6.000000              False
# 2023                   11.0                  8.000000              False
# 2613                    9.0                  3.564727              False
# 2689                    4.0                  1.000000               True
#
#       agotado_despues_socializar_Si
# 399                           False
# 2895                          False
# 2023                          False
# ...

# %%
scaler = StandardScaler()

# Escalamos solo las numéricas en train
X_train_num = pd.DataFrame(
    scaler.fit_transform(X_train[numeric_cols]),
    columns=numeric_cols,
    index=X_train.index
)

# Aplicamos la misma transformación a test
X_test_num = pd.DataFrame(
    scaler.transform(X_test[numeric_cols]),
    columns=numeric_cols,
    index=X_test.index
)

# Concatenamos con las categóricas sin modificar
X_train_std = pd.concat([X_train_num, X_train[categoricas]], axis=1)
X_test_std = pd.concat([X_test_num, X_test[categoricas]], axis=1)
X_train_std.head()
# Out:
#       tiempo_solo  asistencia_eventos_sociales  salir_afuera  \
# 399     -1.301422                     1.051073      1.795231
# 2895    -0.433916                     1.051073      1.344773
# 2023    -1.301422                     0.703792      1.344773
# 2613    -0.433916                     0.009228      1.344773
# 2689     0.144422                    -1.379898     -0.907518
#
#       tamano_circulo_amigos  frecuencia_publicaciones  \
# 399               -0.544557                  0.840945
# 2895              -0.074261                  0.840945
# 2023               1.101479                  1.533798
# 2613               0.631183                 -0.002698
# 2689              -0.544557                 -0.891188
#
#       agotado_despues_socializar_Si  miedo_escenico_Si
# 399                           False              False
# 2895                          False              False
# 2023                          False              False
# ...

# %% [markdown]
# ## 4. 🤖 Entrenamiento y Evaluación <a name="entrenamiento-evaluacion"></a>
#
# Entrenamos con diferentes modelos y comparamos:
# - GradientBoosting
# - Logistic Regression
#
# Evaluamos con:
# - AUC

# %% [markdown]
# *Fuente de la imagen: Hemashreekilari (2023), [Understanding Gradient Boosting](https://medium.com/@hemashreekilari9/understanding-gradient-boosting-632939b98764), Medium.*

# %%
from IPython.display import display, Image, Markdown
display(Image(filename="gradboosting.jpg", width=500))
display(Markdown("*Fuente de la imagen: Hemashreekilari (2023), [Understanding Gradient Boosting](https://medium.com/@hemashreekilari9/understanding-gradient-boosting-632939b98764), Medium.*"))
# Out:
# *Fuente de la imagen: Hemashreekilari (2023), [Understanding Gradient Boosting](https://medium.com/@hemashreekilari9/understanding-gradient-boosting-632939b98764), Medium.*

# %%
display(Image(filename="LR.png", width=300))
display(Markdown("*Fuente de la imagen: Praveen Raj(2023), [Logistic Regression](https://medium.com/@praveenraj.gowd/why-is-logistic-regression-called-logistic-regression-and-not-a-logistic-classification-5a418293040d), Medium.*"))
# Out:
# *Fuente de la imagen: Praveen Raj(2023), [Logistic Regression](https://medium.com/@praveenraj.gowd/why-is-logistic-regression-called-logistic-regression-and-not-a-logistic-classification-5a418293040d), Medium.*

# %%
# Creamos el modelo con los hiperparámetros fijos
clf = GradientBoostingClassifier()
# Entrenamos
clf.fit(X_train_std, y_train)

# Predicciones de probabilidad de que sea clase=1=introvertido según label encoder
y_train_proba = clf.predict_proba(X_train_std)[:, 1]
y_test_proba = clf.predict_proba(X_test_std)[:, 1]

# %%
auc_train = roc_auc_score(y_train, y_train_proba)
auc_test = roc_auc_score(y_test, y_test_proba)

print(f"🧪 AUC en Train: {auc_train:.4f}")
print(f"🧪 AUC en Test:  {auc_test:.4f}")
# Out:
# 🧪 AUC en Train: 0.9807
# 🧪 AUC en Test:  0.9579

# %%
# Definimos los modelos y sus parámetros
models = {
    'GradientBoosting': {
        'estimator': GradientBoostingClassifier(random_state=42),
        'params': {
            'n_estimators': [250, 300, 350, 400, 450],
            'learning_rate': [0.01, 0.1, 0.2],
            'max_depth': [3, 5, 7]
        }
    },
    'LogisticRegression': {
        'estimator': LogisticRegression(max_iter=1000),
        'params': {
            'C': np.logspace(-4, 4, 20),
            'solver': ['lbfgs', 'liblinear']
        }
    }
}

# Entrenamiento y búsqueda
results = {}
for name, cfg in models.items():
    clf = RandomizedSearchCV(
        estimator=cfg['estimator'],
        param_distributions=cfg['params'],
        n_iter=20,
        cv=3,
        scoring='roc_auc',
        n_jobs=-1,
        random_state=42
    )
    clf.fit(X_train_std, y_train)
    results[name] = clf
    print(f"✅ {name} - Mejor AUC (CV): {clf.best_score_:.4f}")
    print(f"🔧 {name} - Mejores parámetros: {clf.best_params_}\n")
# Out:
# ✅ GradientBoosting - Mejor AUC (CV): 0.9665
# 🔧 GradientBoosting - Mejores parámetros: {'n_estimators': 400, 'max_depth': 3, 'learning_rate': 0.01}
#
# ✅ LogisticRegression - Mejor AUC (CV): 0.9435
# 🔧 LogisticRegression - Mejores parámetros: {'solver': 'lbfgs', 'C': np.float64(1438.44988828766)}

# %%
display(Image(filename="cv.png", width=600))
display(Markdown("*Fuente de la imagen: Omkar Hankare(2023), [Cross Validation](https://ompramod.medium.com/cross-validation-623620ff84c2), Medium.*"))
# Out:
# *Fuente de la imagen: Omkar Hankare(2023), [Cross Validation](https://ompramod.medium.com/cross-validation-623620ff84c2), Medium.*

# %%
#ENTRENAR GRADIENT BOOSTING Y CALCULAR AUC POR ETAPA
gb_best = GradientBoostingClassifier(
    learning_rate=0.01,
    max_depth=3,
    n_estimators=400,
    random_state=42
)
gb_best.fit(X_train_std, y_train)

# AUC por etapa
train_auc, test_auc = [], []
for y_train_pred, y_test_pred in zip(gb_best.staged_predict_proba(X_train_std), gb_best.staged_predict_proba(X_test_std)):
    train_auc.append(roc_auc_score(y_train, y_train_pred[:, 1]))
    test_auc.append(roc_auc_score(y_test, y_test_pred[:, 1]))

best_n = np.argmax(test_auc) + 1
print(f'✅ GradientBoosting - Mejor AUC en test: {max(test_auc):.4f} con n_estimators = {best_n}')

#ENTRENAR NUEVO GB CON best_n
gb_best = GradientBoostingClassifier(
    learning_rate=0.01,
    max_depth=3,
    n_estimators=best_n,
    random_state=42
)
gb_best.fit(X_train_std, y_train)
# Out:
# ✅ GradientBoosting - Mejor AUC en test: 0.9608 con n_estimators = 370
# GradientBoostingClassifier(learning_rate=0.01, n_estimators=np.int64(370),
#                            random_state=42)

# %%
# Predicciones de probabilidad
y_train_proba = gb_best.predict_proba(X_train_std)[:, 1]
y_test_proba = gb_best.predict_proba(X_test_std)[:, 1]

auc_train = roc_auc_score(y_train, y_train_proba)
auc_test = roc_auc_score(y_test, y_test_proba)

print(f" AUC en Train: {auc_train:.4f}")
print(f" AUC en Test:  {auc_test:.4f}")
# Out:
#  AUC en Train: 0.9751
#  AUC en Test:  0.9608

# %%
# GRAFICAR AUC vs n_estimators para GB
plt.figure(figsize=(10, 6))
plt.plot(train_auc, label='Train AUC', color='blue')
plt.plot(test_auc, label='Test AUC', color='orange')
plt.axvline(best_n, linestyle='--', color='gray', label=f'Mejor n = {best_n}')
plt.xlabel(f'Número de árboles {best_n}')
plt.ylabel('AUC')
plt.title('Curva de Aprendizaje - Gradient Boosting')
plt.legend()
plt.grid(True)
plt.show()

# %%
# ACÁ VEMOS QUE PASA SI SEGUIMOS AUMENTANDO EL N_ESTIMATORS EMPEZAMOS A PERDER GENERALIZACIÓN
gb_overfit = GradientBoostingClassifier(
    learning_rate=0.01,
    max_depth=3,
    n_estimators=1000,
    random_state=42
)
gb_overfit.fit(X_train_std, y_train)

# AUC por etapa
train_auc_of, test_auc_of = [], []
for y_train_pred, y_test_pred in zip(gb_overfit.staged_predict_proba(X_train_std), gb_overfit.staged_predict_proba(X_test_std)):
    train_auc_of.append(roc_auc_score(y_train, y_train_pred[:, 1]))
    test_auc_of.append(roc_auc_score(y_test, y_test_pred[:, 1]))

#ENTRENAR NUEVO GB CON best_n
gb_overfit = GradientBoostingClassifier(
    learning_rate=0.01,
    max_depth=3,
    n_estimators=1000,
    random_state=42
)
gb_overfit.fit(X_train_std, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.01, n_estimators=1000,
#                            random_state=42)

# %%
# GRAFICAR AUC vs n_estimators para GB overfiteado
plt.figure(figsize=(10, 6))
plt.plot(train_auc_of, label='Train AUC', color='blue')
plt.plot(test_auc_of, label='Test AUC', color='orange')
plt.axvline(370, linestyle='--', color='gray')
plt.xlabel(f'Número de árboles {1000}')
plt.ylabel('AUC')
plt.title('Curva de Aprendizaje 1000n- Gradient Boosting')
plt.legend()
plt.grid(True)
plt.show()

# %%
display(Image(filename="biasvarian.png", width=600))
display(Markdown("*Fuente de la imagen: AnalystPrep(2021), [Generalización](https://analystprep.com/study-notes/cfa-level-2/quantitative-method/overfitting-methods-addressing/), AnalystPrep.*"))
# Out:
# *Fuente de la imagen: AnalystPrep(2021), [Generalización](https://analystprep.com/study-notes/cfa-level-2/quantitative-method/overfitting-methods-addressing/), AnalystPrep.*

# %%
y_proba_gb = gb_best.predict_proba(X_test_std)[:, 1]
auc_gb = roc_auc_score(y_test, y_proba_gb)

#GRAFICAR CURVA ROC
fpr_gb, tpr_gb, _ = roc_curve(y_test, y_proba_gb)

plt.figure(figsize=(10, 6))
plt.plot(fpr_gb, tpr_gb, label=f'Gradient Boosting (AUC = {auc_gb:.3f})', color='darkorange')
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Curva ROC')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Matriz de confusión
plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix(y_test, gb_best.predict(X_test_std)), annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de Confusión')
plt.xlabel('Predicho')
plt.ylabel('Verdadero')
plt.show()

# %% [markdown]
# ## 5. 🔍 Interpretabilidad <a name="importancia-interpretabilidad"></a>
#
# Mostramos qué variables son más relevantes para el modelo:
# - Feature importance (árboles)

# %%
feature_importance = pd.DataFrame({
    'Feature': X_train_std.columns,
    'Importance': gb_best.feature_importances_
}).sort_values(by='Importance', ascending=False)
print("\nFeature Importance:")
print(feature_importance)

# Feature importance bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance)
plt.title('Gradient Boosting Feature Importance')
plt.show()
# Out:
# Feature Importance:
#                          Feature  Importance
# 5  agotado_despues_socializar_Si    0.930523
# 4       frecuencia_publicaciones    0.049217
# 0                    tiempo_solo    0.006369
# 3          tamano_circulo_amigos    0.005568
# 1    asistencia_eventos_sociales    0.005435
# 2                   salir_afuera    0.002871
# 6              miedo_escenico_Si    0.000018

# %% [markdown]
# ## 6. 🌐 Cursos sugeridos <a name="Cursos sugeridos"></a>
#
# Listamos una serie de cursos sugeridos para aprender Python

# %% [markdown]
# Aprender Python nunca fue tan accesible. Estas plataformas ofrecen cursos de calidad para todos los niveles, muchos de ellos gratuitos o con acceso limitado por tiempo:
#
# ---
#
# ### 📘 **LinkedIn Learning**
# - **Python Essential Training** – Curso completo para principiantes.
# - **Learning Python** – Ideal para quienes ya tienen algo de experiencia.
# - *Incluye certificados y pruebas prácticas.*
#
# 🔗 [Explorar en LinkedIn Learning](https://www.linkedin.com/learning/?originalSubdomain=es)
#
# ---
#
# ### 🎓 **Coursera**
# - **Python para todos** – Universidad de Michigan.
# - **Automatización de tareas con Python** – Google.
# - *Cursos con opción gratuita (sin certificado) o con certificado pago.*
#
# 🔗 [Explorar en Coursera](https://www.coursera.org/specializations/python-espanol)
#
# ---
#
# ### 🧠 **edX**
# - **Introducción a Python** – Universidad de Harvard o MIT.
# - **Python para Ciencia de Datos** – Microsoft.
# - *Cursos gratuitos con opción de certificado pago.*
#
# 🔗 [Explorar en edX](https://www.edx.org/es/aprende/programacion-python)
#
# ---
#
# ### 🆓 **Udemy (Gratis)**
# Udemy ofrece cursos algunos destacados:
#
# - [**Curso completo de Python: Programación en Python desde cero**](https://bancogalicia.udemy.com/course/curso-completo-de-python-3/)
# - [**Ultimate Python: de cero a programador experto**](https://bancogalicia.udemy.com/course/ultimate-python-de-cero-a-programador-experto/)
# - [**Curso Maestro de Python: De Cero a Programador Todoterreno**](https://bancogalicia.udemy.com/course/python-3-al-completo-desde-cero/)
